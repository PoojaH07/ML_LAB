# %%
# -*- coding: utf-8 -*-
"""Linear-Regression-Housing_Area_Price.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1CAlZml-P6V2V1RIrodgMfF8L3Ux4V9FT
"""

import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

df = pd.read_csv('housing_area_price.csv')
df

# Commented out IPython magic to ensure Python compatibility.
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker='+')

new_df = df.drop('price',axis='columns')
new_df

price = df.price
price

# Create linear regression object
reg = linear_model.LinearRegression()
reg.fit(new_df,price)

"""(1) Predict price of a home with area = 3300 sqr ft"""

display(reg.predict([[3300]]))

##reg.coef_

##reg.intercept_

"""Y = m * X + b (m is coefficient and b is intercept)"""

3300*135.78767123 + 180616.43835616432

"""(1) Predict price of a home with area = 5000 sqr ft"""
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])
# '(1) Predict price of a home with area = 5000 sqr ft'

# %%
# -*- coding: utf-8 -*-
"""Multiple_LR_HomePrice.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1fK78C8TPV44HdvT6lsMhaau2wMtKXquQ
"""

import pandas as pd
import numpy as np
from sklearn import linear_model

df = pd.read_csv('homeprices_Multiple_LR.csv')
df

"""Data Preprocessing: Fill NA values with median value of a column"""

df.bedrooms.median()

df.bedrooms = df.bedrooms.fillna(df.bedrooms.median())
df

reg = linear_model.LinearRegression()
reg.fit(df.drop('price',axis='columns'),df.price)

reg.coef_

reg.intercept_

"""Find price of home with 3000 sqr ft area, 3 bedrooms, 40 year old"""

reg.predict([[3000, 3, 40]])

112.06244194*3000 + 23388.88007794*3 + -3231.71790863*40 + 221323.00186540384
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 498408.25157402386

# %%
from sklearn import linear_model
import matplotlib.pyplot as plt

# Prepare the data
X = df[['area']]
y = df['price']

# Create and train the linear regression model
reg = linear_model.LinearRegression()
reg.fit(X, y)
# Out:
# LinearRegression()

# %%
# The current 'reg' model was trained on 'area', 'bedrooms', 'age' (from cell sZCbH-I87hHi).
# The original intent of this cell was likely to predict 'income' based on 'year',
# which would require a different model and dataset.
# To make this prediction work with the current 'reg' model, we need to provide
# features that match what it was trained on.

# Assuming we want to predict a home price with specific features (e.g., 2020 sq ft, 3 bedrooms, 15 years old)
home_features_to_predict = pd.DataFrame({'area': [2020], 'bedrooms': [3], 'age': [15]})
predicted_price_for_home = reg.predict(home_features_to_predict)

print(f"Predicted home price for an area of 2020 sq ft, 3 bedrooms, 15 years old: ${predicted_price_for_home[0]:,.2f}")
# Out:
# Predicted home price for an area of 2020 sq ft, 3 bedrooms, 15 years old: $469,380.01

# %%
# -*- coding: utf-8 -*-
"""Linear-Regression-Housing_Area_Price.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1CAlMml-P6V2V1RIrod0MfF8L3Ux4V9FT
"""

import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

df = pd.read_csv('canada_per_capita_income.csv')
df

# Commented out IPython magic to ensure Python compatibility.
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per capita income (US$)') # Corrected ylabel
plt.scatter(df.year,df['per capita income (US$)'],color='red',marker='+') # Corrected columns

new_df = df.drop('per capita income (US$)',axis='columns') # Corrected column to drop
new_df

income = df['per capita income (US$)'] # Corrected variable name and column access
income

# Create linear regression object
reg = linear_model.LinearRegression()
reg.fit(new_df,income) # Fit with new_df (containing 'year') and income

"""(1) Predict per capita income for year = 2020""" # Updated comment

display(reg.predict([[2020]])) # Predict for year 2020

##reg.coef_

##reg.intercept_

"""Y = m * X + b (m is coefficient and b is intercept)"""
# This calculation was for a different model and dataset. Let's recalculate for year 2020 based on the current model.
# You can use reg.coef_ and reg.intercept_ after fitting the model to verify this.
# Example for 2020 (values will be accurate after reg.fit runs):
# 2020 * reg.coef_[0] + reg.intercept_

# Placeholder for the previous hardcoded value; it should be re-evaluated based on the current model.
# 3300*135.78767123 + 180616.43835616432

"""(1) Predict per capita income for year = 2025"""
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
# '(1) Predict per capita income for year = 2025'

# %%
# -*- coding: utf-8 -*-
"""Linear-Regression-Housing_Area_Price.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1CAlMml-P6V2V1RIrod0MfF8L3Ux4V9FT
"""

import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

df = pd.read_csv('canada_per_capita_income.csv')
df

# Commented out IPython magic to ensure Python compatibility.
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per capita income (US$)') # Corrected ylabel
plt.scatter(df.year,df['per capita income (US$)'],color='red',marker='+') # Corrected columns

new_df = df.drop('per capita income (US$)',axis='columns') # Corrected column to drop
new_df

income = df['per capita income (US$)'] # Corrected variable name and column access
income

# Create linear regression object
reg = linear_model.LinearRegression()
reg.fit(new_df,income) # Fit with new_df (containing 'year') and income

"""(1) Predict per capita income for year = 2020""" # Updated comment

display(reg.predict([[2020]])) # Predict for year 2020

##reg.coef_

##reg.intercept_

"""Y = m * X + b (m is coefficient and b is intercept)"""
# This calculation was for a different model and dataset. Let's recalculate for year 2020 based on the current model.
# You can use reg.coef_ and reg.intercept_ after fitting the model to verify this.
# Example for 2020 (values will be accurate after reg.fit runs):
# 2020 * reg.coef_[0] + reg.intercept_

# Placeholder for the previous hardcoded value; it should be re-evaluated based on the current model.
# 3300*135.78767123 + 180616.43835616432

"""(1) Predict per capita income for year = 2025"""
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
# '(1) Predict per capita income for year = 2025'

# %%
display(new_df)
display(income)
# Out:
#     year
# 0   1970
# 1   1971
# 2   1972
# 3   1973
# 4   1974
# 5   1975
# 6   1976
# 7   1977
# 8   1978
# 9   1979
# 10  1980
# 11  1981
# 12  1982
# 13  1983
# 14  1984
# 15  1985
# 16  1986
# 17  1987
# 18  1988
# 19  1989
# 20  1990
# 21  1991
# 22  1992
# 23  1993
# 24  1994
# 25  1995
# 26  1996
# 27  1997
# 28  1998
# 29  1999
# 30  2000
# 31  2001
# 32  2002
# 33  2003
# 34  2004
# 35  2005
# 36  2006
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016
# 0      3399.299037
# 1      3768.297935
# 2      4251.175484
# 3      4804.463248
# 4      5576.514583
# 5      5998.144346
# 6      7062.131392
# 7      7100.126170
# 8      7247.967035
# 9      7602.912681
# 10     8355.968120
# 11     9434.390652
# 12     9619.438377
# 13    10416.536590
# 14    10790.328720
# 15    11018.955850
# 16    11482.891530
# 17    12974.806620
# 18    15080.283450
# 19    16426.725480
# 20    16838.673200
# 21    17266.097690
# ...
