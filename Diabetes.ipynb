# %%
import pandas as pd
df = pd.read_csv("housing.csv")
print("Dataset loaded successfully")
df.info()
df.describe()
df['ocean_proximity'].value_counts()
missing_columns = df.isnull().sum()
missing_columns[missing_columns > 0]

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler, StandardScaler

df = pd.read_csv("Dataset of Diabetes  (1).csv")
print("Dataset loaded successfully")
print(df.head())
print(df.info())

# Clean column names
df.columns = df.columns.str.strip().str.replace(" ", "").str.lower()

print(df.columns)
print(df.head())
# Out:
# Dataset loaded successfully
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         1000 non-null   int64
#  1   No_Pation  1000 non-null   int64
#  2   Gender     1000 non-null   object
#  3   AGE        1000 non-null   int64
#  4   Urea       1000 non-null   float64
#  5   Cr         1000 non-null   int64
#  6   HbA1c      1000 non-null   float64
#  7   Chol       1000 non-null   float64
#  8   TG         1000 non-null   float64
#  9   HDL        1000 non-null   float64
#  10  LDL        1000 non-null   float64
#  11  VLDL       1000 non-null   float64
#  12  BMI        1000 non-null   float64
#  13  CLASS      1000 non-null   object
# dtypes: float64(8), int64(4), object(2)
# memory usage: 109.5+ KB
# None
# Index(['id', 'no_pation', 'gender', 'age', 'urea', 'cr', 'hba1c', 'chol', 'tg',
#        'hdl', 'ldl', 'vldl', 'bmi', 'class'],
#       dtype='object')
#     id  no_pation gender  age  urea  cr  hba1c  chol   tg  hdl  ldl  vldl  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
#
#     bmi class
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
# Clean column names
df.columns = df.columns.str.strip().str.replace(" ", "").str.lower()

print(df.columns)
import numpy as np

cols_with_zero = [
    'urea', 'cr', 'hba1c', 'chol',
    'tg', 'hdl', 'ldl', 'vldl', 'bmi'
]

df[cols_with_zero] = df[cols_with_zero].replace(0, np.nan)



print(df.isnull().sum())
# Out:
# Index(['id', 'no_pation', 'gender', 'age', 'urea', 'cr', 'hba1c', 'chol', 'tg',
#        'hdl', 'ldl', 'vldl', 'bmi', 'class'],
#       dtype='object')
# id           0
# no_pation    0
# gender       0
# age          0
# urea         0
# cr           0
# hba1c        0
# chol         0
# tg           0
# hdl          0
# ldl          0
# vldl         0
# bmi          0
# class        0
# dtype: int64

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
Q1 = df[num_cols].quantile(0.25)
Q3 = df[num_cols].quantile(0.75)
IQR = Q3 - Q1

df = df[~((df[num_cols] < (Q1 - 1.5 * IQR)) |
          (df[num_cols] > (Q3 + 1.5 * IQR))).any(axis=1)]



print("Shape after removing outliers:", df.shape)
# Out:
# Shape after removing outliers: (437, 14)

# %%
cols = ["age", "urea", "cr", "hba1c", "chol",
        "tg", "hdl", "ldl", "vldl", "bmi"]

for x in cols:
    Q1 = df[x].quantile(0.25)
    Q3 = df[x].quantile(0.75)

    IQR = Q3 - Q1

    lowerbound = Q1 - 1.5 * IQR
    upperbound = Q3 + 1.5 * IQR

    df = df[(df[x] >= lowerbound) & (df[x] <= upperbound)]

    print(f"After removing outliers from {x}, shape = {df.shape}")
# Out:
# After removing outliers from age, shape = (437, 14)
# After removing outliers from urea, shape = (437, 14)
# After removing outliers from cr, shape = (437, 14)
# After removing outliers from hba1c, shape = (437, 14)
# After removing outliers from chol, shape = (437, 14)
# After removing outliers from tg, shape = (437, 14)
# After removing outliers from hdl, shape = (437, 14)
# After removing outliers from ldl, shape = (437, 14)
# After removing outliers from vldl, shape = (437, 14)
# After removing outliers from bmi, shape = (437, 14)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df["gender"] = le.fit_transform(df["gender"])
df["class"] = le.fit_transform(df["class"])

print(df.head())
# Out:
#       id  no_pation  gender  age  urea  cr  hba1c  chol   tg  hdl  ldl  vldl  \
# 169  714      34268       1   45   3.6  80    5.0   6.1  3.7  0.7  3.9   1.7
# 170   87      24000       0   50   4.0  56   13.7   4.4  2.0  1.0  2.5   0.9
# 171  231      14389       0   50   4.0  56   13.7   4.4  2.0  1.0  2.5   0.9
# 172  505      23044       0   48   4.0  38    6.5   4.4  2.3  1.3  2.2   1.0
# 174    7      34278       0   46   3.0  59    5.1   5.7  3.8  1.3  2.8   1.7
#
#       bmi  class
# 169  22.0      0
# 170  29.0      0
# 171  29.0      0
# 172  23.0      0
# 174  24.0      0
